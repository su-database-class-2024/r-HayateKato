# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)
# Out:
# /usr/local/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='convenience' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0     6795909545   None           None             None               None
# 1     4081142569   None           None             None               None
# 2     6795909641   None           None               13               None
# 3     6898525166   None           None             None               None
# 4     6661634907   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 399   9161249410   None           None             None               None
# 400   9149671133   None           None             None               None
# 401   3744122599   None           None             None               None
# 402   3745337529   None           None             None               None
# 403  12288690630   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle       brand  \
# 0          None      None    None    None  None    None    None      LAWSON
# 1          None      None    None    None  None    None    None  FamilyMart
# 2          None      None    None    None  None    None    None    セブン-イレブン
# 3          None      None    None    None  None    None    None      ミニストップ
# 4          None      None    None    None  None    None    None    セブン-イレブン
# ..          ...       ...     ...     ...   ...     ...     ...         ...
# 399        None      None    None    None  None    None    None        ローソン
# 400        None      None    None    None  None    None    None        ローソン
# 401        None      None    None    None  None    None    None    セブン-イレブン
# 402        None      None    None    None  None    None    None    セブン-イレブン
# 403        None      None    None    None  None    None    None      LAWSON
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 399   None     None     None    None         None    None    None    None
# 400   None     None     None    None         None    None    None    None
# 401   None     None     None    None         None    None    None    None
# 402   None     None     None    None         None    None    None    None
# 403   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 399         None    None  None       None  None             None    None
# 400         None    None  None       None  None             None    None
# 401         None    None  None       None  None             None    None
# 402         None    None  None       None  None             None    None
# 403         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 399    None     None  None         None     None    None  None    None  None
# 400    None     None  None         None     None    None  None    None  None
# 401    None     None  None         None     None    None  None    None  None
# 402    None     None  None         None     None    None  None    None  None
# 403    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar              name natural office oneway  \
# 0       None     None     None              ローソン    None   None   None
# 1       None     None     None          ファミリーマート    None   None   None
# 2       None     None     None          セブン-イレブン    None   None   None
# 3       None     None     None            ミニストップ    None   None   None
# 4       None     None     None          セブン-イレブン    None   None   None
# ..       ...      ...      ...               ...     ...    ...    ...
# 399     None     None     None    ローソンさいたま白幡三丁目店    None   None   None
# 400     None     None     None    ローソンさいたま白幡四丁目店    None   None   None
# 401     None     None     None          セブン-イレブン    None   None   None
# 402     None     None     None  セブンイレブンさいたま辻5丁目店    None   None   None
# 403     None     None     None     ローソンさいたま辻五丁目店    None   None   None
#
#     operator place   poi population power power_source public_transport  \
# 0       None  None  None       None  None         None             None
# 1       None  None  None       None  None         None             None
# 2       None  None  None       None  None         None             None
# 3       None  None  None       None  None         None             None
# 4       None  None  None       None  None         None             None
# ..       ...   ...   ...        ...   ...          ...              ...
# 399     None  None  None       None  None         None             None
# 400     None  None  None       None  None         None             None
# 401     None  None  None       None  None         None             None
# 402     None  None  None       None  None         None             None
# 403     None  None  None       None  None         None             None
#
#     railway   ref religion route service         shop sport surface  toll  \
# 0      None  None     None  None    None  convenience  None    None  None
# 1      None  None     None  None    None  convenience  None    None  None
# 2      None  None     None  None    None  convenience  None    None  None
# 3      None  None     None  None    None  convenience  None    None  None
# 4      None  None     None  None    None  convenience  None    None  None
# ..      ...   ...      ...   ...     ...          ...   ...     ...   ...
# 399    None  None     None  None    None  convenience  None    None  None
# 400    None  None     None  None    None  convenience  None    None  None
# 401    None  None     None  None    None  convenience  None    None  None
# 402    None  None     None  None    None  convenience  None    None  None
# 403    None  None     None  None    None  convenience  None    None  None
#
#     tourism tower:type tunnel water waterway wetland width  wood z_order  \
# 0      None       None   None  None     None    None  None  None    None
# 1      None       None   None  None     None    None  None  None    None
# 2      None       None   None  None     None    None  None  None    None
# 3      None       None   None  None     None    None  None  None    None
# 4      None       None   None  None     None    None  None  None    None
# ..      ...        ...    ...   ...      ...     ...   ...   ...     ...
# 399    None       None   None  None     None    None  None  None    None
# 400    None       None   None  None     None    None  None  None    None
# 401    None       None   None  None     None    None  None  None    None
# 402    None       None   None  None     None    None  None  None    None
# 403    None       None   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15540181.501 4295281.306)
# 1    POINT (15539656.930 4295032.874)
# 2    POINT (15540543.356 4293188.963)
# 3    POINT (15540249.662 4293338.940)
# 4    POINT (15540245.020 4293894.136)
# ..                                ...
# 399  POINT (15546168.964 4279206.824)
# 400  POINT (15546190.282 4278690.677)
# 401  POINT (15545980.422 4278310.304)
# 402  POINT (15546662.688 4277948.536)
# 403  POINT (15546781.589 4277766.847)
#
# [404 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0f85099d0ccde439b173da8e930a4ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0f85099d0ccde439b173da8e930a4ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0f85099d0ccde439b173da8e930a4ed = L.map(
#                 &quot;map_a0f85099d0ccde439b173da8e930a4ed&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6da916c85b3858ca9c4b2efa513a8ae7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#             var marker_d2acf1744295a45e7404ff2deb43d974 = L.marker(
#                 [35.96118139973169, 139.5998256],
#                 {}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#         var popup_23d95956e973279b9da0148a6ca287bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da15e57580de20074942d20a14a9daa0 = $(`&lt;div id=&quot;html_da15e57580de20074942d20a14a9daa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ローソン&lt;/div&gt;`)[0];
#                 popup_23d95956e973279b9da0148a6ca287bd.setContent(html_da15e57580de20074942d20a14a9daa0);
#
#
#
#         marker_d2acf1744295a45e7404ff2deb43d974.bindPopup(popup_23d95956e973279b9da0148a6ca287bd)
#         ;
#
#
#
#
#             var marker_6fd77df7701e10ffe0a8ca540c44e18e = L.marker(
#                 [35.95937499973153, 139.5951133],
#                 {}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#         var popup_794e7e1283a42d8b7e547462df54ba9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f926d9392f9f86094dfa11e69471489 = $(`&lt;div id=&quot;html_7f926d9392f9f86094dfa11e69471489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ファミリーマート&lt;/div&gt;`)[0];
#                 popup_794e7e1283a42d8b7e547462df54ba9a.setContent(html_7f926d9392f9f86094dfa11e69471489);
#
#
#
#         marker_6fd77df7701e10ffe0a8ca540c44e18e.bindPopup(popup_794e7e1283a42d8b7e547462df54ba9a)
#         ;
#
#
#
#
#             var marker_ac11c66db4a866062f0da8d78eedddd5 = L.marker(
#                 [35.94596629973021, 139.6030762],
#                 {}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#         var popup_4ec8adf59209099692eedec7ea0132e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70df406668381a361a9a4ba9e36f2b5f = $(`&lt;div id=&quot;html_70df406668381a361a9a4ba9e36f2b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_4ec8adf59209099692eedec7ea0132e2.setContent(html_70df406668381a361a9a4ba9e36f2b5f);
#
#
#
#         marker_ac11c66db4a866062f0da8d78eedddd5.bindPopup(popup_4ec8adf59209099692eedec7ea0132e2)
#         ;
#
#
#
#
#             var marker_94069a186e0806d6779f79ce7648d13d = L.marker(
#                 [35.94705699973032, 139.6004379],
#                 {}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#         var popup_a4069095959546adb2071f0417b3316f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f5ac15e6865edfcebd13695cde61173 = $(`&lt;div id=&quot;html_7f5ac15e6865edfcebd13695cde61173&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ミニストップ&lt;/div&gt;`)[0];
#                 popup_a4069095959546adb2071f0417b3316f.setContent(html_7f5ac15e6865edfcebd13695cde61173);
#
#
#
#         marker_94069a186e0806d6779f79ce7648d13d.bindPopup(popup_a4069095959546adb2071f0417b3316f)
#         ;
#
#
#
#
#             var marker_b63e8d1ae5bd6ce0440e3e099092033f = L.marker(
#                 [35.95109449973071, 139.6003962],
#                 {}
#             ).addTo(map_a0f85099d0ccde439b173da8e930a4ed);
#
#
#         var popup_e2dc616a7c3e14c594bc1d74b9da340c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dfff422765c6a23737ccf6b209b2010 = $(`&lt;div id=&quot;html_9dfff422765c6a23737ccf6b209b2010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_e2dc616a7c3e14c594bc1d74b9da340c.setContent(html_9dfff422765c6a23737ccf6b209b2010);
#
#
#
#         marker_b63e8d1ae5bd6ce0440e3e099092033f.bindPopup(popup_e2dc616a7c3e14c594bc1d74b9da340c)
#         ;
#
#
#
#
#             var marker_105c7824164fc159a7268e14760a2661 = L.marker(
#                 [35.950547599730655, 139
